# %%
#Step 01 Load Data Set


dataset = '/content/drive/MyDrive/AI_ML/Employee_StudyHours.csv'
import pandas as pd

df = pd.read_csv(dataset) #Data Frame

# %%
df
# Out:
#     Hours  Scores
# 0     2.5    21.0
# 1     5.1    47.0
# 2     3.2    27.0
# 3     8.5    75.0
# 4     3.5    30.0
# 5     1.5    20.0
# 6     9.2    88.0
# 7     5.5    60.0
# 8     8.3    81.0
# 9     2.7    25.0
# 10    7.7    85.0
# 11    NaN    85.0
# 12    5.9    62.0
# 13    4.5    41.0
# 14    3.3    42.0
# 15    1.1    17.0
# 16    8.9    95.0
# 17    2.5    30.0
# 18    3.4     NaN
# 19    1.9    24.0
# 20    6.1    67.0
# 21    7.4    69.0
# 22    2.7    30.0
# 23    4.8    54.0
# 24    3.8    35.0
# 25    6.9    76.0
# 26    7.8    86.0
# 27    1.3    19.0
# 28    2.6    30.0
# 29    6.1    63.0
# 30    NaN     NaN
# 31    5.6    60.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import altair as alt
# from google.colab import autoviz
# df_2103414750949536881 = autoviz.get_registered_df('df_2103414750949536881')
#
# ...

# %%
df.head(5)
# Out:
#    Hours  Scores
# 0    2.5    21.0
# 1    5.1    47.0
# 2    3.2    27.0
# 3    8.5    75.0
# 4    3.5    30.0

# %%
df.shape
# Out:
# (32, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Hours   30 non-null     float64
#  1   Scores  30 non-null     float64
# dtypes: float64(2)
# memory usage: 640.0 bytes

# %%
df.keys()
# Out:
# Index(['Hours', 'Scores'], dtype='object')

# %%
#Step 02 Visualization of Dataset
import matplotlib.pyplot as plt

plt.scatter(df.Hours , df['Scores'] , marker='*')
plt.xlabel("Hours ------>")
plt.ylabel("Estimated Score ------>")
plt.title("Employee Score Probability")
plt.show()

# %%
#Seaborn

import seaborn as sns

def get_heatmap(df):
  plt.figure(figsize=(6,4))
  sns.heatmap(df.isnull(),yticklabels=False , cbar=False , cmap='viridis')
  return plt.show()

get_heatmap(df)

# %%
#Set 03 Preprocessing the Dataset

# %%
#Treating Missing Values

# df.dropna()   drop all null values

median_v = df.Hours.median()
mean_v = df.Scores.mean()

print(median_v)
print(mean_v)
# Out:
# 4.65
# 51.46666666666667

# %%
import math
df['Hours'] = df.Hours.fillna(median_v)
df['Scores'] = df.Scores.fillna(mean_v)

df
# Out:
#     Hours     Scores
# 0    2.50  21.000000
# 1    5.10  47.000000
# 2    3.20  27.000000
# 3    8.50  75.000000
# 4    3.50  30.000000
# 5    1.50  20.000000
# 6    9.20  88.000000
# 7    5.50  60.000000
# 8    8.30  81.000000
# 9    2.70  25.000000
# 10   7.70  85.000000
# 11   4.65  85.000000
# 12   5.90  62.000000
# 13   4.50  41.000000
# 14   3.30  42.000000
# 15   1.10  17.000000
# 16   8.90  95.000000
# 17   2.50  30.000000
# 18   3.40  51.466667
# 19   1.90  24.000000
# 20   6.10  67.000000
# 21   7.40  69.000000
# 22   2.70  30.000000
# 23   4.80  54.000000
# 24   3.80  35.000000
# 25   6.90  76.000000
# 26   7.80  86.000000
# 27   1.30  19.000000
# 28   2.60  30.000000
# 29   6.10  63.000000
# 30   4.65  51.466667
# 31   5.60  60.000000

# %%
get_heatmap(df)

# %%
#Step 04 Loading Data
#For ML model we can only feed data in the form of array & the array should be in 2D

# %%
#Mathod 01
X = df.iloc[:,:-1].values
Y = df.iloc[:,-1:].values

X
# Out:
# array([[2.5 ],
#        [5.1 ],
#        [3.2 ],
#        [8.5 ],
#        [3.5 ],
#        [1.5 ],
#        [9.2 ],
#        [5.5 ],
#        [8.3 ],
#        [2.7 ],
#        [7.7 ],
#        [4.65],
#        [5.9 ],
#        [4.5 ],
#        [3.3 ],
#        [1.1 ],
#        [8.9 ],
#        [2.5 ],
#        [3.4 ],
#        [1.9 ],
#        [6.1 ],
#        [7.4 ],
#        [2.7 ],
#        [4.8 ],
#        [3.8 ],
#        [6.9 ],
#        [7.8 ],
#        [1.3 ],
#        [2.6 ],
#        [6.1 ],
#        [4.65],
#        [5.6 ]])

# %%
#Method 02
import numpy as np

X = np.array(df[['Hours']])
Y = np.array(df[['Scores']])

X
# Out:
# array([[2.5 ],
#        [5.1 ],
#        [3.2 ],
#        [8.5 ],
#        [3.5 ],
#        [1.5 ],
#        [9.2 ],
#        [5.5 ],
#        [8.3 ],
#        [2.7 ],
#        [7.7 ],
#        [4.65],
#        [5.9 ],
#        [4.5 ],
#        [3.3 ],
#        [1.1 ],
#        [8.9 ],
#        [2.5 ],
#        [3.4 ],
#        [1.9 ],
#        [6.1 ],
#        [7.4 ],
#        [2.7 ],
#        [4.8 ],
#        [3.8 ],
#        [6.9 ],
#        [7.8 ],
#        [1.3 ],
#        [2.6 ],
#        [6.1 ],
#        [4.65],
#        [5.6 ]])

# %%
#Step 05 Splitting Data - Train Set & Test Set

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2)

X_train
# Out:
# array([[8.9 ],
#        [4.8 ],
#        [1.5 ],
#        [7.7 ],
#        [4.65],
#        [6.9 ],
#        [5.5 ],
#        [8.5 ],
#        [3.5 ],
#        [2.5 ],
#        [1.1 ],
#        [3.2 ],
#        [9.2 ],
#        [2.7 ],
#        [3.8 ],
#        [1.3 ],
#        [3.4 ],
#        [2.6 ],
#        [7.4 ],
#        [2.5 ],
#        [5.9 ],
#        [1.9 ],
#        [3.3 ],
#        [7.8 ],
#        [5.1 ]])

# %%
# Step 06 Train the Model / Feeding the Mode / Fitting the Algo

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
x_pred = model.predict(Y_yest)
y_pred
# Out:
# array([[50.56688897],
#        [64.35531964],
#        [59.60068837],
#        [64.35531964],
#        [85.2756972 ],
#        [32.02382703],
#        [49.14049959]])

# %%
#Evaluation Method
#from sklearn.metrics import accuracy_score
#from sklearn.metrics import classification_report

# %%
#Step 08 Performance Evaluation
model.score(X_test,Y_test)*100
# Out:
# 92.87200864936145

# %%
model.score(X_train,Y_train)*100
# Out:
# 86.88511390629397

# %%
model.score(X,Y)*100
# Out:
# 87.65334739185823

# %%
import matplotlib.pyplot as plt

plt.scatter(X_train , Y_train , marker='*')
plt.xlabel("Hours ------>")
plt.ylabel("Estimated Score ------>")
plt.title("Employee Score Probability")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter( X_test, Y_test , marker='*')
plt.xlabel("Hours ------>")
plt.ylabel("Estimated Score ------>")
plt.title("Employee Score Probability")
plt.show()

# %%
import matplotlib.pyplot as plt

plt.scatter(X , Y , marker='*')
plt.xlabel("Hours ------>")
plt.ylabel("Estimated Score ------>")
plt.title("Employee Score Probability")
plt.show()

# %%
#Visualizing Result

# %%
#y = mx+c
model.coef_
# Out:
# array([[9.50926253]])

# %%
model.intercept_
# Out:
# array([6.34881821])

# %%
#y = (9.5)x+5.5 #----> Best Fit Line

# %%
y_pred = model.coef_*X+model.intercept_

#Plotting
plt.scatter(X,Y)
plt.plot(X,y_pred)

# %%
# Training Set Evaluation

# %%
plt.scatter(X_train,Y_train, color ='red')
plt.plot(X_train, model.predict(X_train))
plt.show()

# %%
HourStudied = int(input("enter hours studied"))

y_pred = model.coef_*HourStudied+model.intercept_

y_pred
# Out:
# enter hours studied7
# array([[72.91365591]])
